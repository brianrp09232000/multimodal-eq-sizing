# %%
# !rm -rf /kaggle/working/multimodal-eq-sizing

# %%
# !git clone https://github.com/brianrp09232000/multimodal-eq-sizing.git /kaggle/working/multimodal-eq-sizing
# Out:
# Cloning into '/kaggle/working/multimodal-eq-sizing'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 70 (delta 13), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (70/70), 12.41 KiB | 2.07 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
import os, sys, yaml, pathlib

repo_root = pathlib.Path("/kaggle/working/multimodal-eq-sizing")
sys.path.append(str(repo_root))

print("Repo exists:", repo_root.exists())
# Out:
# Repo exists: True

# %%
from src.utils import logging

# %%
logging.check_function_callable()
# Out:
# Source functions are now available in /kaggle/working/multimodal-eq-sizing
